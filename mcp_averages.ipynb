# %%
import pandas as pd
from pathlib import Path

# %%
toon_data_to_load = Path("mcp_toon_data.csv")

# %%
toon_data = pd.read_csv(toon_data_to_load)
toon_data
# Out:
#               Name  Threat  Healthy Stam  Injured Stam  Stam Total    Move  \
# 0      Black Widow     2.0           4.0           4.0         8.0    Long
# 1              Bob     2.0           3.0           3.0         6.0  Medium
# 2         Bullseye     2.0           4.0           4.0         8.0  Medium
# 3     Honey Badger     2.0           5.0           4.0         9.0  Medium
# 4           Nebula     2.0           4.0           5.0         9.0    Long
# 5            Okoye     2.0           4.0           4.0         8.0  Medium
# 6   Rocket Raccoon     2.0           3.0           3.0         6.0  Medium
# 7             Toad     2.0           5.0           3.0         8.0  Medium
# 8             Wong     2.0           4.0           4.0         8.0  Medium
# 9              NaN     NaN           NaN           NaN         NaN     NaN
# 10             NaN     NaN           NaN           NaN         NaN     NaN
# ...
